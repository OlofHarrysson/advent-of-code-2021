# %%
from csv import reader
nr_list = []
box_list = []
with open('exer4_nr.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    for row in csv_reader:
        nr_list.append(row)


with open('exer4_boxes.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    for row in csv_reader:
        box_list.append(row)

row_list = []
col_list = []
x = 5
for i in range(599):
    if i == x:
        x+=6
        col_list.append([box_list[i-5][0][0:2],box_list[i-4][0][0:2],box_list[i-3][0][0:2],box_list[i-2][0][0:2],box_list[i-1][0][0:2]])
    else:
        row_list.append(box_list[i][0])
      

for a in range(len(nr_list[0])):
    for b in range(len(row_list)):
        rights = 0
        for c in range(a):
            if int(nr_list[0][c]) == int(row_list[b][0:2]) or int(nr_list[0][c]) ==  int(row_list[b][3:5]) or int(nr_list[0][c]) ==  int(row_list[b][6:8]) or int(nr_list[0][c]) == int(row_list[b][9:11]) or int(nr_list[0][c]) == int(row_list[b][12:14]):
                rights +=1
                if rights >4:
                    print(f"Nr{a}, Box {b/5} har {rights} rätt!")
                    row_sum =(int(row_list[b][0:2]) + int(row_list[b][3:5]) + int(row_list[b][6:8]) + int(row_list[b][9:11]) + int(row_list[b][12:14]))
                    print(row_sum * (int(nr_list[0][c])))
                    print(a+1)
                    print(nr_list[0][c])
                    print(row_list[b])
                    
rights = 0
for a in range(len(nr_list[0])):
    for b in range(len(col_list)):
        rights = 0
        for c in range(a):
            if int(nr_list[0][c]) == int(col_list[b][0]) or int(nr_list[0][c]) ==  int(col_list[b][1]) or int(nr_list[0][c]) ==  int(col_list[b][2]) or int(nr_list[0][c]) == int(col_list[b][3]) or int(nr_list[0][c]) == int(col_list[b][4]):
                rights +=1
                if rights >4:
                    print(f"Nr{a}, Box {b/5} har {rights} rätt!")
                    row_sum =(int(row_list[b][0:2]) + int(row_list[b][3:5]) + int(row_list[b][6:8]) + int(row_list[b][9:11]) + int(row_list[b][12:14]))
                    print(row_sum*(a+1))
# Out:
# Nr26, Box 73.4 har 5 rätt!
# 14112
# 27
# 42
# 31 96 42 81 86
# Nr27, Box 73.4 har 5 rätt!
# 14112
# 28
# 42
# 31 96 42 81 86
# Nr28, Box 73.4 har 5 rätt!
# 14112
# 29
# 42
# 31 96 42 81 86
# Nr29, Box 73.4 har 5 rätt!
# 14112
# 30
# 42
# 31 96 42 81 86
# Nr30, Box 73.4 har 5 rätt!
# 14112
# 31
# 42
# 31 96 42 81 86
# Nr31, Box 73.4 har 5 rätt!
# 14112
# 32
# 42
# 31 96 42 81 86
# Nr32, Box 73.4 har 5 rätt!
# 14112
# 33
# 42
# 31 96 42 81 86
# Nr32, Box 79.8 har 5 rätt!
# 8814
# 33
# 26
# 77 26 74 71 91
# Nr33, Box 73.4 har 5 rätt!
# 14112
# 34
# 42
# 31 96 42 81 86
# Nr33, Box 79.8 har 5 rätt!
# 8814
# 34
# 26
# 77 26 74 71 91
# Nr34, Box 73.4 har 5 rätt!
# 14112
# 35
# 42
# 31 96 42 81 86
# Nr34, Box 79.8 har 5 rätt!
# 8814
# 35
# 26
# 77 26 74 71 91
# Nr35, Box 73.4 har 5 rätt!
# 14112
# 36
# 42
# 31 96 42 81 86
# Nr35, Box 79.8 har 5 rätt!
# 8814
# 36
# 26
# 77 26 74 71 91
# Nr36, Box 73.4 har 5 rätt!
# 14112
# 37
# 42
# 31 96 42 81 86
# Nr36, Box 79.8 har 5 rätt!
# 8814
# 37
# ...
